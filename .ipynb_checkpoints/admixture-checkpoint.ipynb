# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

from scipy.stats import ttest_1samp
from itertools import product

from ancestrator import *

# %%
from itertools import product

sns.set_context('notebook',font_scale=1.25)
sns.set_style('white')

source_labels = ['1000Genomes']
samplegroup_labels = ['LEA']
panel_labels = [
    'CPx10',
#  'GAL_Affy_SubPanel_100',
#  'GAL_Affy_SubPanel_75',
#  'GAL_Affy_SubPanel_60',
#  'GAL_Affy_SubPanel_65',
#  'GAL_Affy_SubPanel_50',
#  'GAL_Affy_SubPanel_45',
#  'GAL_Affy_SubPanel_40',
#  'GAL_Affy_SubPanel_35',
#  'GAL_Affy_SubPanel_30',
#  'GAL_Affy_SubPanel_20',
#  'GAL_Affy_SubPanel_10',
#  'GAL_Affy_SubPanel_5'
]
Ks = [3]

combo = product(source_labels, panel_labels, samplegroup_labels)

for source_label, panel_label, samplegroup_label in combo:
    dataset = Dataset(source_label, samplegroup_label, panel_label)
    admixture = dataset.admixture(Ks=Ks, cores=4)
    
    admixture.plot_cv_errors()
    
    for K in Ks:
        fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 5))
        admixture.plot(ax=ax1, K=K)
        admixture.plot(ax=ax2, K=K, population_means=True)
        ax2.set_title('')

        plt.tight_layout()
        plt.show()
        
        if K == 3:
            admixture.plot_triangle()

# %% [markdown]
# # Compare admixture ratios for GAl_Completo vs GAL_Affy

# %%
df = admix_test.tail(10).applymap(lambda x: round(100*x, 1))

print('Panel GAL_Completo (445 AIMs)')
print()
print('Panel GAL_Affy (179 AIMs)')
print()
print('Subpanel de GAL_Affy (50 AIMs)')
df.reset_index('sample').reset_index(drop=True).set_index('sample')
# Out:
# Panel GAL_Completo (445 AIMs)
#
# Panel GAL_Affy (179 AIMs)
#
# Subpanel de GAL_Affy (50 AIMs)
#           AMR   EUR   AFR
# sample
# NA19780  22.6  61.5  15.9
# NA19782  47.7  36.6  15.7
# NA19783  79.7  20.3   0.0
# NA19785  73.5  26.5   0.0
# NA19786  45.8  48.6   5.6
# NA19788  62.5  32.1   5.4
# NA19789  50.5  36.8  12.7
# NA19792  29.5  66.7   3.8
# NA19794  25.4  68.4   6.2
# NA19795  41.2  39.9  18.9

# %%
sns.set_style('white')

panel_labels = [
    'GAL_Affy',
    'GAL_Affy_SubPanel_50',
#     'GAL_Affy_SubPanel_25',
#     'GAL_Affy_SubPanel_15'
]

for panel_label in panel_labels:
    reference = Dataset('1000Genomes', 'LEA', 'GAL_Completo')
    test = Dataset('1000Genomes', 'LEA', panel_label)

    admix_ref = reference.admixture(Ks=3).result[3]
    admix_test = test.admixture(Ks=3).result[3]

    diff = admix_ref - admix_test
    diff = diff.applymap(lambda x: round(100*x, 1))
    diff = diff.reset_index().drop(['family', 'sample'], axis=1)
    diff = diff[diff['region'] == 'AMR']

    fig, axes = plt.subplots(3, 1, sharex=True)
    axes = list(axes)
    for region in ['AMR', 'EUR', 'AFR']:
        ax = axes.pop(0)
        diff.hist(column=region, ax=ax)
        ax.set_ylim([0, 125])
        ax.set_xlim([-50, 50])
    ax.set_xlabel('Puntos percentuales de diferencia\n'
                  'en la ancestría estimada, entre paneles')
    fig.suptitle(test.panel.label)
    sns.despine(left=True)
    plt.show()

# %% [markdown]
# # Paired $t$-test

# %%
panel_labels = [p for p in Panel.available_panels()
                if re.match('(GAL_Affy|GAL_Completo)', p)]
panel_labels.pop(0)

aims_count = lambda p: len(Panel(p).snps)
panel_labels = sorted(panel_labels, key=aims_count, reverse=True)
reference_panel_label = 'GAL_Completo'

# %% [markdown]
# Student's $t$ statistic: $t_{s} = \frac{\bar{x} - \mu_{0}}{s/\sqrt{n}}$

# %%
ancestries_to_test = ['AMR', 'EUR', 'AFR']
K = 3
samplegroup_label = 'LEA' ###

ref_dataset = Dataset('1000Genomes', samplegroup_label, reference_panel_label)
ref_admix = ref_dataset.admixture(Ks=K)

ttest_results = pd.DataFrame({'panel': [], 'ancestry': [], 'p_value': []})
ttest_results = ttest_results.set_index(['panel', 'ancestry'])['p_value']

for panel_label in panel_labels:
    dataset = Dataset('1000Genomes', samplegroup_label, panel_label)
    admix = dataset.admixture(Ks=K)
    diff = ref_admix.result[K] - admix.result[K]

    for ancestry in ancestries_to_test:
        ttest = ttest_1samp(diff[ancestry], 0)
        ttest_results.loc[(panel_label, ancestry)] = ttest.pvalue

# %%
sns.set_context('notebook', font_scale=1.5)
sns.set_style('ticks')

fig, ax = plt.subplots(figsize=(15, 5))
results_df = ttest_results
results_df.unstack('ancestry').plot(ax=ax, rot=90, linestyle='dotted', marker='o')

sns.despine(bottom=False, left=True)
ax.set_xticks(np.arange(len(panel_labels)))
ax.set_xticklabels(panel_labels)
ax.axhline(0.05, linestyle='solid', linewidth=0.75, color='black')
ax.set_ylim([0, 1])
ax.set_yticks([0, 1])
ax.set_ylabel('p-value')
ax.set_xlim([-0.5, len(panel_labels) - 0.5])
ax.text(8, 0.055, '$p = 0.05$', fontsize=20, horizontalalignment='center')
plt.show()
