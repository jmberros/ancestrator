# %%
# %matplotlib inline

from ancestrator import *

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from itertools import product


sns.set_context('notebook')
sns.set_style('white')

panel_labels = ['GAL_Completo', 'GAL_Affy', 'CPx1']
samplegroup_labels = ['LEA']
source_labels = ['1000Genomes']
components = [['PC1', 'PC2']]
combos = list(product(source_labels, samplegroup_labels, panel_labels, components))

plotw, ploth = 6, 6
ncols, nrows = len(list(combos)), 2
fig = plt.figure(figsize=(ncols * plotw, nrows * ploth))
ax_ids = list(np.arange(ncols * nrows) + 1)

for s, sg, p, components in combos:
    dataset = Dataset(s, sg, p)
    smartpca = dataset.pca(implementation='smartpca')
    smartpca.plot(ax=fig.add_subplot(nrows, ncols, ax_ids.pop(0)), components_to_plot=components)
    
sns.despine(left=True, bottom=True)
plt.tight_layout()
# Out:
# /home/juan/software/eigensoft6/src/eigensrc/smartpca -p /home/juan/tesina/1000Genomes/datasets/LEA.GAL_Completo.pca.par
# /home/juan/software/eigensoft6/src/eigensrc/smartpca -p /home/juan/tesina/1000Genomes/datasets/LEA.GAL_Affy.pca.par
# /home/juan/software/eigensoft6/src/eigensrc/smartpca -p /home/juan/tesina/1000Genomes/datasets/LEA.CPx1.pca.par
